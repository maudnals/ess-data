# %%
import pandas as pd;
import plotly.plotly as plt;
import plotly.figure_factory as pltff;
import plotly.graph_objs as pltgo;
import numpy as np;
import seaborn as sns;



################
# DATA
################
df = pd.read_csv("https://raw.githubusercontent.com/maudnals/ess-data/master/ESS1-8e01-2.csv")
dfs_by_country = {
#     cleanup happiness since we'll ue it extensively. Values > 10 are used for N/A ans such.
    "DE": df[df.cntry == "DE"][df.happy > 10],
    "FR": df[df.cntry == "FR"][df.happy > 10],
    "FI": df[df.cntry == "FI"][df.happy > 10],
};



################
# UTILS.PLOT
################
color_DE = '#F1C122';
color_FI = '#1F94E5';
color_FR = '#C0189C';
marker_DE = dict(
                size = 10,
                color = color_DE,
                line = dict(
                    width = 2,
                )
            );
marker_FI = dict(
                size = 10,
                color = color_FI,
                line = dict(
                    width = 2,
                )
            );
marker_FR = dict(
                size = 10,
                color = color_FR,
                line = dict(
                    width = 2,
                )
            );



################
# UTILS.DATA
################
def mean_for_ess_round(essround, cntry, col_name):
    df = dfs_by_country[cntry];
    return df[df.essround == essround][col_name].mean();

def mean_for_month(month, cntry, col_name):
    df = dfs_by_country[cntry];
    return df[df.inwmm == month][col_name].mean();

def std_for_ess_round(essround, cntry, col_name):
    df = dfs_by_country[cntry];
    return df[df.essround == essround][col_name].std();

def mean_happiness_for_ess_round(essround, cntry):
    return mean_for_ess_round(essround, cntry, "happy");

def std_happiness_for_ess_round(essround, cntry):
    return std_for_ess_round(essround, cntry, "happy");
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
################
# HAPPINESS ACROSS TIMES FOR ALL COUNTRIES
################

rounds = list(range(1,9));
# happinesses = list(map(mean_happiness_for_ess_round, rounds));

# better, more python: list comprehension (source https://stackoverflow.com/questions/10973766/understanding-the-map-function)
happinesses_DE = [mean_happiness_for_ess_round(r, "DE") for r in rounds]
happinesses_FI = [mean_happiness_for_ess_round(r, "FI") for r in rounds]
happinesses_FR = [mean_happiness_for_ess_round(r, "FR") for r in rounds]

# Plot happinesses = f(ess round);
trace_DE = pltgo.Scatter(x = rounds, 
            y = happinesses_DE, 
            name = 'Germany',
            mode = 'lines', 
            marker = marker_DE);
trace_FR = pltgo.Scatter(x = rounds, 
            y = happinesses_FR, 
            name = 'France',
            mode = 'lines', 
            marker = marker_FR);
trace_FI = pltgo.Scatter(x = rounds, 
            y = happinesses_FI, 
            name = 'Finland',
            mode = 'lines', 
            marker = marker_FI);


    
fig = pltgo.Figure(
    data=[trace_DE, trace_FI, trace_FR], 
    layout=pltgo.Layout(
        paper_bgcolor='#0A010F', 
        plot_bgcolor="#0A010F", 
        title="Happiness = f(ESS Round)", 
        font = {"family": "Courier New", "color": "white"},
        xaxis = {"color": "grey", "title": "ESS Round # (every other year since 2002)", "gridcolor": "#2B2B2B"},
        yaxis = {"color": "grey", "title": "Happiness Level", "gridcolor": "#2B2B2B"} 
    ));

plt.iplot(fig)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/223.embed" height="525px" width="100%"></iframe>

# %%
################
# STANDARD DEVIATION + VIOLIN
################

# list comprehension
# tuples: simpler than dicos!
mean_std_happiness_DE = [(mean_happiness_for_ess_round(r, "DE"), std_happiness_for_ess_round(r, "DE")) for r in rounds];
mean_std_happiness_FI = [(mean_happiness_for_ess_round(r, "FI"), std_happiness_for_ess_round(r, "FI")) for r in rounds];
mean_std_happiness_FR = [(mean_happiness_for_ess_round(r, "FR"), std_happiness_for_ess_round(r, "FR")) for r in rounds];

def mean_happiness(tupl):
    return tupl[0]

mean_std_happiness_DE.sort(key=mean_happiness)
mean_std_happiness_FI.sort(key=mean_happiness)
mean_std_happiness_FR.sort(key=mean_happiness)

trace_mstd_DE = pltgo.Scatter(x = [i[0] for i in mean_std_happiness_DE], 
            y = [i[1] for i in mean_std_happiness_DE],  
            mode = 'lines', 
            marker = marker_DE);
trace_mstd_FI = pltgo.Scatter(x = [i[0] for i in mean_std_happiness_FI], 
            y = [i[1] for i in mean_std_happiness_FI],  
            mode = 'lines', 
            marker = marker_FI);
trace_mstd_FR = pltgo.Scatter(x = [i[0] for i in mean_std_happiness_FR], 
            y = [i[1] for i in mean_std_happiness_FR],  
            mode = 'lines', 
            marker = marker_FR);


fig_violin_DE = pltgo.Figure(
    data=[{"type":"violin", "y": dfs_by_country["DE"][dfs_by_country["DE"].essround == 9]["happy"]}], 
    layout=pltgo.Layout(
        paper_bgcolor='#0A010F', 
        plot_bgcolor="#0A010F", 
        title="Violin DE", 
        font = {"family": "Courier New", "color": "white"},
    )
);

plt.iplot(fig_violin)



# fig = pltff.create_violin(y, title='Violin Plot', colors='#604d9e', paper_bgcolor='#0A010F', 
#         plot_bgcolor="#0A010F", 
#         font = {"family": "Courier New", "color": "white"})
# plt.iplot(fig, filename='violin-visual')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/253.embed" height="525px" width="100%"></iframe>

# %%
fig_violin_DE = pltgo.Figure(
    data=[{"type":"violin", "y": dfs_by_country["DE"][dfs_by_country["DE"].essround == 8]["happy"]}], 
    layout=pltgo.Layout(
        paper_bgcolor='#0A010F', 
        plot_bgcolor="#0A010F", 
        title="Violin DE", 
        font = {"family": "Courier New", "color": "white"},
    )
);

plt.iplot(fig_violin)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-35-f9effc2fb975> in <module>
#       9 );
#      10
# ---> 11 plt.iplot(fig_violin)
#
# /usr/local/lib/python3.6/dist-packages/plotly/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     140     if 'auto_open' not in plot_options:
#     141         plot_options['auto_open'] = False
# --> 142     url = plot(figure_or_data, **plot_options)
#     143
#     144     if isinstance(figure_or_data, dict):
#
# /usr/local/lib/python3.6/dist-packages/plotly/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     237     data = fig.get('data', [])
#     238     plot_options['layout'] = fig.get('layout', {})
# --> 239     response = v1.clientresp(data, **plot_options)
#     240
#     241     # Check if the url needs a secret key
#
# /usr/local/lib/python3.6/dist-packages/plotly/api/v1/clientresp.py in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /usr/local/lib/python3.6/dist-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# /usr/local/lib/python3.6/dist-packages/retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# /usr/local/lib/python3.6/dist-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/dist-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# /usr/local/lib/python3.6/dist-packages/plotly/api/v1/utils.py in request(method, url, **kwargs)
#      88         content = response.content if response else 'No content'
#      89         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 90     validate_response(response)
#      91     return response
#
# /usr/local/lib/python3.6/dist-packages/plotly/api/v1/utils.py in validate_response(response)
#      38         message = content if content else 'No Content'
#      39
# ---> 40     raise exceptions.PlotlyRequestError(message, status_code, content)
#      41
#      42
#
# PlotlyRequestError: Hi there, you've reached the threshold of 100 combined image exports and chart saves per 24h period. If you need to raise your daily limit, please consider upgrading to a paid plan
# (see: https://plot.ly/products/cloud ).

# %%
################
# COUNTRIES MOST IMPACTED BY SEASONAL VARIATIONS: N/U (not usable)
################

# v = [mean_for_month(m, "DE", "happy") for m in list(range(1, 12))]
# w = [mean_for_month(m, "FR", "happy") for m in list(range(1, 12))]
# v = [mean_for_month(m, "FI", "happy") for m in list(range(1, 12))]

# Data missing
# [7.255780346820809,
#  7.594713656387666,
#  6.916666666666667,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  7.2,
#  7.424242424242424,
#  7.32289156626506]

# %%
################
# HAPPINESS BY AGE
################

happiness_by_age_DE = dfs_by_country["DE"].groupby(["agea"], as_index=False).mean();
happiness_by_age_FI = dfs_by_country["FI"].groupby(["agea"], as_index=False).mean();
happiness_by_age_FR = dfs_by_country["FR"].groupby(["agea"], as_index=False).mean();

happiness_by_age_DE.agea

tr_h_age_DE = pltgo.Scatter(x = happiness_by_age_DE.agea, 
            y = happiness_by_age_DE.happy, 
            name = 'Germany',
            mode = 'lines', 
            marker = marker_DE);

tr_h_age_FI = pltgo.Scatter(x = happiness_by_age_FI.agea, 
            y = happiness_by_age_FI.happy, 
            name = 'Finland',
            mode = 'lines', 
            marker = marker_FI);

tr_h_age_FR = pltgo.Scatter(x = happiness_by_age_FR.agea, 
            y = happiness_by_age_FR.happy, 
            name = 'France',
            mode = 'lines', 
            marker = marker_FR);

plt.iplot([tr_h_age_DE, tr_h_age_FI, tr_h_age_FR])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-90e827f3116d> in <module>
#       3 ################
#       4
# ----> 5 happiness_by_age_DE = dfs_by_country["DE"].groupby(["agea"], as_index=False).mean();
#       6 happiness_by_age_FI = dfs_by_country["FI"].groupby(["agea"], as_index=False).mean();
#       7 happiness_by_age_FR = dfs_by_country["FR"].groupby(["agea"], as_index=False).mean();
#
# NameError: name 'dfs_by_country' is not defined

# %%
################
# HAPPINESS BY HOUSEHOLD SIZE
################

happiness_by_household_DE = dfs_by_country["DE"].groupby(["hhmmb"], as_index=False).mean();
happiness_by_household_FI = dfs_by_country["FI"].groupby(["hhmmb"], as_index=False).mean();
happiness_by_household_FR = dfs_by_country["FR"].groupby(["hhmmb"], as_index=False).mean();

tr_h_house_DE = pltgo.Scatter(x = happiness_by_household_DE.hhmmb, 
            y = happiness_by_household_DE.happy, 
            name = 'Germany',
            mode = 'lines', 
            marker = marker_DE);

tr_h_house_FI = pltgo.Scatter(x = happiness_by_household_FI.hhmmb, 
            y = happiness_by_household_FI.happy, 
            name = 'Finland',
            mode = 'lines', 
            marker = marker_FI);

tr_h_house_FR = pltgo.Scatter(x = happiness_by_household_FR.hhmmb, 
            y = happiness_by_household_FR.happy, 
            name = 'France',
            mode = 'lines', 
            marker = marker_FR);


plt.iplot([tr_h_house_DE, tr_h_house_FI, tr_h_house_FR])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/161.embed" height="525px" width="100%"></iframe>

# %%
################
# RESPONDANTS AGE DISTRIBUTION
################
# grouped_by_age_DE = dfs_by_country["DE"].groupby(["agea"], as_index=False);

# .size();
# happiness_by_household_FI = dfs_by_country["FI"].groupby(["agea"], as_index=False).mean();
# happiness_by_household_FR = dfs_by_country["FR"].groupby(["agea"], as_index=False).mean();

tr_ages_DE = pltgo.Histogram(
    x = dfs_by_country["DE"]['agea'].tolist(),
    name='DE',
    marker=dict(color = color_DE),
    opacity=0.75
)


tr_ages_FI = pltgo.Histogram(
    x = dfs_by_country["FI"]['agea'].tolist(),
    name='FI',
    marker=dict(color = color_FI),
    opacity=0.75
)


tr_ages_FR = pltgo.Histogram(
    x = dfs_by_country["FR"]['agea'].tolist(),
    name='FR',
    marker=dict(color = color_FR),
    opacity=0.75
)

plt.iplot([tr_ages_DE, tr_ages_FI, tr_ages_FR])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/119.embed" height="525px" width="100%"></iframe>

# %%
################
# HAPPINESS BY HUMAN VALUE
################

human_values = ["imprich", "ipshabt", "iprspot", "ipsuces", 
                "iphlppl", "ipudrst", "iplylfr", "impenv", "ipeqopt", 
                "impsafe", "ipfrule", "ipmodst" , "ipstrgv", "ipbhprp", "imptrad",
                "impdiff", "ipcrtiv", "ipgdtim","impfree", "ipadvnt", "impfun"
                ];

means_happiness_by_human_value = [dfs_by_country["DE"][dfs_by_country["DE"][i] < 3]["happy"].mean() for i in human_values];
means_happiness_by_human_value_df = pd.DataFrame(means_happiness_by_human_value);
# min-max normalization
means_happiness_by_human_value_normalized_df=(means_happiness_by_human_value_df-means_happiness_by_human_value_df.min())/(means_happiness_by_human_value_df.max()-means_happiness_by_human_value_df.min())

color_se = "red";
color_st = "green";
color_c = "blue";
color_o = "yellow";

colors_by_human_values = {
    "imprich": color_se, "ipshabt": color_se, "iprspot": color_se, "ipsuces": color_se, 
    "iphlppl": color_st, "ipudrst": color_st, "iplylfr": color_st, "impenv": color_st, "ipeqopt": color_st, 
    "impsafe": color_c, "ipfrule": color_c, "ipmodst": color_c , "ipstrgv": color_c, "ipbhprp": color_c, "imptrad": color_c,
     "impdiff": color_o, "ipcrtiv": color_o, "ipgdtim": color_o,"impfree": color_o, "ipadvnt": color_o, "impfun": color_o
}

means_happiness_by_human_value_normalized_df
plt.iplot([
            pltgo.Bar(
                x=human_values, 
                y=means_happiness_by_human_value_normalized_df[0].tolist(), 
                marker=dict(color=[colors_by_human_values[i] for i in human_values]))
        ]);


# takaway: you're most likely to be happy if you consider it very important
# you're least likely to be happy if you consider other people important
# happiness > 7
# average yellow valuation < 3
# happiness level = f(second most important group)

# let's look at the happy people who consider yellow group very important. 
# What is their second values? What do they value less?
# Which are the happiest
#  ++++++ TODO

# %%
################
# 2D HIST PLOTS: POPULATION DISTRIBUTION
################

data_histo_2d_happiness_age = [
    pltgo.Histogram2d(x=df_DE[df_DE["agea"] < 103][["agea"]]["agea"].tolist(), y=df_DE[["happy"]]["happy"].tolist(),
        colorscale=[[0, 'rgb(12,51,131)'], [0.25, 'rgb(10,136,186)'], [0.5, 'rgb(242,211,56)'], [0.75, 'rgb(242,143,56)'], [1, 'rgb(217,30,30)']]
    )
]
plt.iplot(data_histo_2d_happiness_age)

data_histo_2d_happiness_hhmmb = [
    pltgo.Histogram2d(x=df_DE[df_DE["hhmmb"] < 12][["hhmmb"]]["hhmmb"].tolist(), y=df_DE[["happy"]]["happy"].tolist(),
        colorscale=[[0, 'rgb(12,51,131)'], [0.25, 'rgb(10,136,186)'], [0.5, 'rgb(242,211,56)'], [0.75, 'rgb(242,143,56)'], [1, 'rgb(217,30,30)']]
    )
]

plt.iplot(data_histo_2d_happiness_hhmmb)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/153.embed" height="525px" width="100%"></iframe>

# %%
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~xyzzyx/157.embed" height="525px" width="100%"></iframe>

# %%
################
# CORRELATION: HAPPINESS VS OTHER FEATURES
################


corr_happiness_others = dfs_by_country["DE"][["agea", "happy", "sclmeet", "health", 
                             "hlthhmp", "hhmmb", "gndr", 
                             "partner", "chldhhe", 
                             "edulvla", "eduyrs", "wkhtot"]].corr();
corr_happiness_others.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col3 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col5 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col6 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col7 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col8 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col9 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col10 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row0_col11 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col0 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col5 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col6 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col7 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col9 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col10 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row1_col11 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col1 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col3 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col4 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col5 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col6 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col7 {
#             background-color:  #6fa7ce;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col8 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col9 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col10 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row2_col11 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col2 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col4 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col5 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col6 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col7 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col8 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col9 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row3_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col0 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col3 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col5 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col7 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col9 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col10 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_5518dde0_2ccb_11e9_9acb_6e902ca1cd18row4_col11 {
#             background-color:  #abbfdc;
#             color:  #0

# %%
corr_happiness_values = dfs_by_country["DE"][["happy", "imprich", "ipshabt", "iprspot", "ipsuces", 
                "iphlppl", "ipudrst", "iplylfr", "impenv", "ipeqopt", 
                "impsafe", "ipfrule", "ipmodst" , "ipstrgv", "ipbhprp", "imptrad",
                "impdiff", "ipcrtiv", "ipgdtim","impfree", "ipadvnt", "impfun"
                ]].corr();
corr_happiness_values.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col11 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col12 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col13 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col14 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col15 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col16 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col17 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col18 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col19 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col20 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row0_col21 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col0 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col2 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col4 {
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col5 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col6 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col7 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col8 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col9 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col10 {
#             background-color:  #adc1dd;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col11 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col12 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col13 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col14 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col15 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col16 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col17 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col18 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col19 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col20 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row1_col21 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col0 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col1 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col3 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col4 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col6 {
#             background-color:  #65a3cb;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col7 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col8 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col9 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col10 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col11 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col12 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col13 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col14 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_6734b210_2ccb_11e9_9acb_6e902ca1cd18row2_col15 {
#             background-color:  #bbc7e0;

# %%
dfs_by_country["DE"][["happy", "imprich", "ipshabt", "iprspot", "ipsuces", 
                "iphlppl", "ipudrst", "iplylfr", "impenv", "ipeqopt", 
                "impsafe", "ipfrule", "ipmodst" , "ipstrgv", "ipbhprp", "imptrad",
                "impdiff", "ipcrtiv", "ipgdtim","impfree", "ipadvnt", "impfun"
                ]].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1a9dc74ae28> in <module>
# ----> 1 dfs_by_country["DE"][["happy", "imprich", "ipshabt", "iprspot", "ipsuces",
#       2                 "iphlppl", "ipudrst", "iplylfr", "impenv", "ipeqopt",
#       3                 "impsafe", "ipfrule", "ipmodst" , "ipstrgv", "ipbhprp", "imptrad",
#       4                 "impdiff", "ipcrtiv", "ipgdtim","impfree", "ipadvnt", "impfun"
#       5                 ]].corr()
#
# NameError: name 'dfs_by_country' is not defined

# %%
dfs_by_country["DE"]

# %%
model = RandomForestRegressor(n_estimators=10, max_features=2)
# model.fit(features, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-010d308ff3d5> in <module>
# ----> 1 model = RandomForestRegressor(n_estimators=10, max_features=2)
#       2 # model.fit(features, labels)
#
# NameError: name 'RandomForestRegressor' is not defined

# %%
# STANDARD DEVIATION, STATISTICAL SIGNIFICANCE
# HOUSEHOLD SIZE AND AGE AND HAPPINESS (heatmap)
# VALUES AND HAPPINESS
# VALUES ACROSS AGES
# VALUES: SAY AND DO
# MACHINE LEARNING
